# %%
#Import keras library
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Activation, Flatten, Dropout, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras import regularizers, optimizers
#Import numpy library
import numpy as np
#Import matplotlib library
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
#Import dataset
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
#Convert values into float type
x_train = x_train.astype('float32')
y_train = y_train.astype('float32')
#Create a validation set
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]
#Understand dimensions
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 8s 0us/step
# (45000, 32, 32, 3) (45000, 1)
# (5000, 32, 32, 3) (5000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
#Normalize data by substracting the mean, dividing by standard deviation plus an small number
mean = np.mean(x_train, axis=(0,1,2,3))
std = np.std(x_train, axis=(0,1,2,3))
x_train = (x_train - mean)/(std+1e-7)
x_valid = (x_valid - mean)/(std+1e-7)
x_test = (x_test - mean)/(std+1e-7)

# %%
#One-hot encode the classes
y_train = np_utils.to_categorical(y_train,10)
y_valid = np_utils.to_categorical(y_valid,10)
y_test = np_utils.to_categorical(y_test,10)
print(y_train.shape,y_valid.shape,y_test.shape)

# %%
#Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(x_train)

# %%
model = Sequential()
#Conv1
model.add(Conv2D(32,kernel_size=3,padding='same',kernel_regularizer=regularizers.l2(1e-4),input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())
#Conv2
model.add(Conv2D(32,kernel_size=3,padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#Pool + dropout
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

#Conv3
model.add(Conv2D(64,kernel_size=3,padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#Conv4
model.add(Conv2D(64,kernel_size=3,padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#Pool + dropout
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.3))

#Conv5
model.add(Conv2D(128,kernel_size=3,padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#Conv6
model.add(Conv2D(128,kernel_size=3,padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(Activation('relu'))
model.add(BatchNormalization())
#Pool + dropout
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.4))

#Flatten and add dense layer
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath='model.100epochs.hdf5',verbose=1,save_best_only=True)
optimizer=keras.optimizers.adam(learning_rate=0.0001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit_generator(datagen.flow(x_train,y_train,batch_size=128),callbacks=[checkpointer],steps_per_epoch=x_train.shape[0]//128,epochs=125,verbose=2,validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/125
#  - 31s - loss: 2.8462 - accuracy: 0.2648 - val_loss: 1.9922 - val_accuracy: 0.3136
#
# Epoch 00001: val_loss improved from inf to 1.99222, saving model to model.100epochs.hdf5
# Epoch 2/125
#  - 22s - loss: 2.1216 - accuracy: 0.3471 - val_loss: 1.5617 - val_accuracy: 0.4752
#
# Epoch 00002: val_loss improved from 1.99222 to 1.56167, saving model to model.100epochs.hdf5
# Epoch 3/125
#  - 22s - loss: 1.8950 - accuracy: 0.3963 - val_loss: 1.4296 - val_accuracy: 0.5086
#
# Epoch 00003: val_loss improved from 1.56167 to 1.42955, saving model to model.100epochs.hdf5
# Epoch 4/125
#  - 23s - loss: 1.7469 - accuracy: 0.4323 - val_loss: 1.4398 - val_accuracy: 0.5088
#
# Epoch 00004: val_loss did not improve from 1.42955
# Epoch 5/125
#  - 22s - loss: 1.6546 - accuracy: 0.4625 - val_loss: 1.4120 - val_accuracy: 0.5138
#
# Epoch 00005: val_loss improved from 1.42955 to 1.41204, saving model to model.100epochs.hdf5
# Epoch 6/125
#  - 22s - loss: 1.5667 - accuracy: 0.4878 - val_loss: 1.3978 - val_accuracy: 0.5242
#
# Epoch 00006: val_loss improved from 1.41204 to 1.39780, saving model to model.100epochs.hdf5
# Epoch 7/125
#  - 22s - loss: 1.5051 - accuracy: 0.5069 - val_loss: 1.3440 - val_accuracy: 0.5416
#
# Epoch 00007: val_loss improved from 1.39780 to 1.34400, saving model to model.100epochs.hdf5
# Epoch 8/125
#  - 22s - loss: 1.4248 - accuracy: 0.5355 - val_loss: 1.3084 - val_accuracy: 0.5626
#
# Epoch 00008: val_loss improved from 1.34400 to 1.30840, saving model to model.100epochs.hdf5
# Epoch 9/125
#  - 22s - loss: 1.3753 - accuracy: 0.5458 - val_loss: 1.2938 - val_accuracy: 0.5548
#
# Epoch 00009: val_loss improved from 1.30840 to 1.29381, saving model to model.100epochs.hdf5
# Epoch 10/125
#  - 22s - loss: 1.3181 - accuracy: 0.5680 - val_loss: 1.2665 - val_accuracy: 0.5688
#
# Epoch 00010: val_loss improved from 1.29381 to 1.26653, saving model to model.100epochs.hdf5
# Epoch 11/125
#  - 22s - loss: 1.2759 - accuracy: 0.5800 - val_loss: 1.1723 - val_accuracy: 0.6010
#
# Epoch 00011: val_loss improved from 1.26653 to 1.17230, saving model to model.100epochs.hdf5
# Epoch 12/125
#  - 22s - loss: 1.2188 - accuracy: 0.5973 - val_loss: 1.1628 - val_accuracy: 0.6058
#
# Epoch 00012: val_loss improved from 1.17230 to 1.16282, saving model to model.100epochs.hdf5
# Epoch 13/125
#  - 22s - loss: 1.1901 - accuracy: 0.6089 - val_loss: 1.0971 - val_accuracy: 0.6298
#
# Epoch 00013: val_loss improved from 1.16282 to 1.09709, saving model to model.100epochs.hdf5
# Epoch 14/125
#  - 22s - loss: 1.1425 - accuracy: 0.6200 - val_loss: 1.1763 - val_accuracy: 0.6062
#
# Epoch 00014: val_loss did not improve from 1.09709
# Epoch 15/125
#  - 22s - loss: 1.1120 - accuracy: 0.6335 - val_loss: 1.0380 - val_accuracy: 0.6556
#
# Epoch 00015: val_loss improved from 1.09709 to 1.03805, saving model to model.100epochs.hdf5
# Epoch 16/125
#  - 22s - loss: 1.0729 - accuracy: 0.6433 - val_loss: 1.0737 - val_accuracy: 0.6476
#
# Epoch 00016: val_loss did not improve from 1.03805
# Epoch 17/125
#  - 22s - loss: 1.0550 - accuracy: 0.6493 - val_loss: 1.0006 - val_accuracy: 0.6736
#
# Epoch 00017: val_loss improved from 1.03805 to 1.00061, saving model to model.100epochs.hdf5
# Epoch 18/125
#  - 22s - loss: 1.0251 - accuracy: 0.6596 - val_loss: 1.0302 - val_accuracy: 0.6674
#
# Epoch 00018: val_loss did not improve from 1.00061
# Epoch 19/125
#  - 22s - loss: 1.0025 - accuracy: 0.6655 - val_loss: 1.0145 - val_accuracy: 0.6758
#
# Epoch 00019: val_loss did not improve from 1.00061
# Epoch 20/125
#  - 22s - loss: 0.9762 - accuracy: 0.6750 - val_loss: 0.9642 - val_accuracy: 0.6848
#
# Epoch 00020: val_loss improved from 1.00061 to 0.96421, saving model to model.100epochs.hdf5
# Epoch 21/125
#  - 22s - loss: 0.9561 - accuracy: 0.6837 - val_loss: 0.9556 - val_accuracy: 0.6904
#
# Epoch 00021: val_loss improved from 0.96421 to 0.95562, saving model to model.100epochs.hdf5
# Epoch 22/125
#  - 22s - loss: 0.9428 - accuracy: 0.6876 - val_loss: 0.9344 - val_accuracy: 0.7020
#
# Epoch 00022: val_loss improved from 0.95562 to 0.93439, saving model to model.100epochs.hdf5
# Epoch 23/125
#  - 22s - loss: 0.9224 - accuracy: 0.6924 - val_loss: 0.9150 - val_accuracy: 0.7032
#
# Epoch 00023: val_loss improved from 0.93439 to 0.91501, saving model to model.100epochs.hdf5
# Epoch 24/125
#  - 22s - loss: 0.9111 - accuracy: 0.6977 - val_loss: 0.8750 - val_accuracy: 0.7184
#
# Epoch 00024: val_loss improved from 0.91501 to 0.87502, saving model to model.100epochs.hdf5
# Epoch 25/125
#  - 22s - loss: 0.8919 - accuracy: 0.7048 - val_loss: 0.8974 - val_accuracy: 0.7136
#
# Epoch 00025: val_loss did not improve from 0.87502
# Epoch 26/125
#  - 22s - loss: 0.8756 - accuracy: 0.7065 - val_loss: 0.8465 - val_accuracy: 0.7256
#
# Epoch 00026: val_loss improved from 0.87502 to 0.84654, saving model to model.100epochs.hdf5
# Epoch 27/125
#  - 22s - loss: 0.8597 - accuracy: 0.7137 - val_loss: 0.8455 - val_accuracy: 0.7282
#
# Epoch 00027: val_loss improved from 0.84654 to 0.84550, saving model to model.100epochs.hdf5
# Epoch 28/125
#  - 22s - loss: 0.8537 - accuracy: 0.7134 - val_loss: 0.8279 - val_accuracy: 0.7364
#
# Epoch 00028: val_loss improved from 0.84550 to 0.82786, saving model to model.100epochs.hdf5
# Epoch 29/125
#  - 22s - loss: 0.8334 - accuracy: 0.7222 - val_loss: 0.8258 - val_accuracy: 0.7366
#
# Epoch 00029: val_loss improved from 0.82786 to 0.82579, saving model to model.100epochs.hdf5
# Epoch 30/125
#  - 22s - loss: 0.8214 - accuracy: 0.7269 - val_loss: 0.8318 - val_accuracy: 0.7364
#
# Epoch 00030: val_loss did not improve from 0.82579
# Epoch 31/125
#  - 22s - loss: 0.8102 - accuracy: 0.7273 - val_loss: 0.7773 - val_accuracy: 0.7532
#
# Epoch 00031: val_loss improved from 0.82579 to 0.77729, saving model to model.100epochs.hdf5
# Epoch 32/125
#  - 22s - loss: 0.8027 - accuracy: 0.7317 - val_loss: 0.7954 - val_accuracy: 0.7446
#
# Epoch 00032: val_loss did not improve from 0.77729
# Epoch 33/125
#  - 22s - loss: 0.7904 - accuracy: 0.7364 - val_loss: 0.7937 - val_accuracy: 0.7482
#
# Epoch 00033: val_loss did not improve from 0.77729
# Epoch 34/125
#  - 22s - loss: 0.7752 - accuracy: 0.7421 - val_loss: 0.7788 - val_accuracy: 0.7552
#
# Epoch 00034: val_loss did not improve from 0.77729
# Epoch 35/125
#  - 22s - loss: 0.7712 - accuracy: 0.7407 - val_loss: 0.7415 - val_accuracy: 0.7576
#
# Epoch 00035: val_loss improved from 0.77729 to 0.74150, saving model to model.100epochs.hdf5
# Epoch 36/125
#  - 22s - loss: 0.7601 - accuracy: 0.7449 - val_loss: 0.7299 - val_accuracy: 0.7654
#
# Epoch 00036: val_loss improved from 0.74150 to 0.72994, saving model to model.100epochs.hdf5
# Epoch 37/125
#  - 22s - loss: 0.7476 - accuracy: 0.7502 - val_loss: 0.7043 - val_accuracy: 0.7756
#
# Epoch 00037: val_loss improved from 0.72994 to 0.70428, saving model to model.100epochs.hdf5
# Epoch 38/125
#  - 22s - loss: 0.7444 - accuracy: 0.7535 - val_loss: 0.7134 - val_accuracy: 0.7742
#
# Epoch 00038: val_loss did not improve from 0.70428
# Epoch 39/125
#  - 22s - loss: 0.7300 - accuracy: 0.7574 - val_loss: 0.7151 - val_accuracy: 0.7764
#
# Epoch 00039: val_loss did not improve from 0.70428
# Epoch 40/125
#  - 22s - loss: 0.7262 - accuracy: 0.7564 - val_loss: 0.7216 - val_accuracy: 0.7764
#
# Epoch 00040: val_loss did not improve from 0.70428
# Epoch 41/125
#  - 22s - loss: 0.7165 - accuracy: 0.7619 - val_loss: 0.7109 - val_accuracy: 0.7748
#
# Epoch 00041: val_loss did not improve from 0.70428
# Epoch 42/125
#  - 22s - loss: 0.7062 - accuracy: 0.7654 - val_loss: 0.6346 - val_accuracy: 0.7982
#
# Epoch 00042: val_loss improved from 0.70428 to 0.63462, saving model to model.100epochs.hdf5
# Epoch 43/125
#  - 22s - loss: 0.7045 - accuracy: 0.7662 - val_loss: 0.6395 - val_accuracy: 0.7966
#
# Epoch 00043: val_loss did not improve from 0.63462
# Epoch 44/125
#  - 22s - loss: 0.6987 - accuracy: 0.7674 - val_loss: 0.6409 - val_accuracy: 0.7986
#
# Epoch 00044: val_loss did not improve from 0.63462
# Epoch 45/125
#  - 22s - loss: 0.6887 - accuracy: 0.7717 - val_loss: 0.6352 - val_accuracy: 0.7994
#
# Epoch 00045: val_loss did not improve from 0.63462
# Epoch 46/125
#  - 22s - loss: 0.6751 - accuracy: 0.7764 - val_loss: 0.7118 - val_accuracy: 0.7746
#
# Epoch 00046: val_loss did not improve from 0.63462
# Epoch 47/125
#  - 22s - loss: 0.6729 - accuracy: 0.7792 - val_loss: 0.6672 - val_accuracy: 0.7890
#
# Epoch 00047: val_loss did not improve from 0.63462
# Epoch 48/125
#  - 22s - loss: 0.6650 - accuracy: 0.7800 - val_loss: 0.6657 - val_accuracy: 0.7904
#
# Epoch 00048: val_loss did not improve from 0.63462
# Epoch 49/125
#  - 22s - loss: 0.6673 - accuracy: 0.7798 - val_loss: 0.6551 - val_accuracy: 0.7908
#
# Epoch 00049: val_loss did not improve from 0.63462
# Epoch 50/125
#  - 22s - loss: 0.6553 - accuracy: 0.7819 - val_loss: 0.6275 - val_accuracy: 0.7960
#
# Epoch 00050: val_loss improved from 0.63462 to 0.62747, saving model to model.100epochs.hdf5
# Epoch 51/125
#  - 22s - loss: 0.6522 - accuracy: 0.7842 - val_loss: 0.6428 - val_accuracy: 0.8028
#
# Epoch 00051: val_loss did not improve from 0.62747
# Epoch 52/125
#  - 22s - loss: 0.6456 - accuracy: 0.7850 - val_loss: 0.6517 - val_accuracy: 0.7986
#
# Epoch 00052: val_loss did not improve from 0.62747
# Epoch 53/125
#  - 22s - loss: 0.6427 - accuracy: 0.7863 - val_loss: 0.6391 - val_accuracy: 0.8018
#
# Epoch 00053: val_loss did not improve from 0.62747
# Epoch 54/125
#  - 22s - loss: 0.6367 - accuracy: 0.7899 - val_loss: 0.5689 - val_accuracy: 0.8246
#
# Epoch 00054: val_loss improved from 0.62747 to 0.56895, saving model to model.100epochs.hdf5
# Epoch 55/125
#  - 22s - loss: 0.6268 - accuracy: 0.7924 - val_loss: 0.6028 - val_accuracy: 0.8096
#
# Epoch 00055: val_loss did not improve from 0.56895
# Epoch 56/125
#  - 22s - loss: 0.6262 - accuracy: 0.7928 - val_loss: 0.5937 - val_accuracy: 0.8132
#
# Epoch 00056: val_loss did not improve from 0.56895
# Epoch 57/125
#  - 22s - loss: 0.6146 - accuracy: 0.7955 - val_loss: 0.5932 - val_accuracy: 0.8134
#
# Epoch 00057: val_loss did not improve from 0.56895
# Epoch 58/125
#  - 22s - loss: 0.6117 - accuracy: 0.7991 - val_loss: 0.5892 - val_accuracy: 0.8148
#
# Epoch 00058: val_loss did not improve from 0.56895
# Epoch 59/125
#  - 22s - loss: 0.6090 - accuracy: 0.8016 - val_loss: 0.6131 - val_accuracy: 0.8056
#
# Epoch 00059: val_loss did not improve from 0.56895
# Epoch 60/125
#  - 22s - loss: 0.6062 - accuracy: 0.8006 - val_loss: 0.5660 - val_accuracy: 0.8246
#
# Epoch 00060: val_loss improved from 0.56895 to 0.56600, saving model to model.100epochs.hdf5
# Epoch 61/125
#  - 22s - loss: 0.6015 - accuracy: 0.8033 - val_loss: 0.5947 - val_accuracy: 0.8092
#
# Epoch 00061: val_loss did not improve from 0.56600
# Epoch 62/125
#  - 22s - loss: 0.5981 - accuracy: 0.8031 - val_loss: 0.6014 - val_accuracy: 0.8130
#
# Epoch 00062: val_loss did not improve from 0.56600
# Epoch 63/125
#  - 22s - loss: 0.5867 - accuracy: 0.8048 - val_loss: 0.5677 - val_accuracy: 0.8204
#
# Epoch 00063: val_loss did not improve from 0.56600
# Epoch 64/125
#  - 22s - loss: 0.5932 - accuracy: 0.8055 - val_loss: 0.5600 - val_accuracy: 0.8242
#
# Epoch 00064: val_loss improved from 0.56600 to 0.55996, saving model to model.100epochs.hdf5
# Epoch 65/125
#  - 22s - loss: 0.5837 - accuracy: 0.8054 - val_loss: 0.5746 - val_accuracy: 0.8180
#
# Epoch 00065: val_loss did not improve from 0.55996
# Epoch 66/125
#  - 22s - loss: 0.5854 - accuracy: 0.8059 - val_loss: 0.5873 - val_accuracy: 0.8144
#
# Epoch 00066: val_loss did not improve from 0.55996
# Epoch 67/125
#  - 22s - loss: 0.5764 - accuracy: 0.8104 - val_loss: 0.5606 - val_accuracy: 0.8250
#
# Epoch 00067: val_loss did not improve from 0.55996
# Epoch 68/125
#  - 22s - loss: 0.5731 - accuracy: 0.8124 - val_loss: 0.5459 - val_accuracy: 0.8316
#
# Epoch 00068: val_loss improved from 0.55996 to 0.54590, saving model to model.100epochs.hdf5
# Epoch 69/125
#  - 22s - loss: 0.5667 - accuracy: 0.8132 - val_loss: 0.5659 - val_accuracy: 0.8256
#
# Epoch 00069: val_loss did not improve from 0.54590
# Epoch 70/125
#  - 22s - loss: 0.5626 - accuracy: 0.8171 - val_loss: 0.5562 - val_accuracy: 0.8250
#
# Epoch 00070: val_loss did not improve from 0.54590
# Epoch 71/125
#  - 22s - loss: 0.5677 - accuracy: 0.8141 - val_loss: 0.5365 - val_accuracy: 0.8282
#
# Epoch 00071: val_loss improved from 0.54590 to 0.53655, saving model to model.100epochs.hdf5
# Epoch 72/125
#  - 22s - loss: 0.5546 - accuracy: 0.8182 - val_loss: 0.5605 - val_accuracy: 0.8192
#
# Epoch 00072: val_loss did not improve from 0.53655
# Epoch 73/125
#  - 22s - loss: 0.5578 - accuracy: 0.8165 - val_loss: 0.5547 - val_accuracy: 0.8222
#
# Epoch 00073: val_loss did not improve from 0.53655
# Epoch 74/125
#  - 22s - loss: 0.5456 - accuracy: 0.8206 - val_loss: 0.5282 - val_accuracy: 0.8382
#
# Epoch 00074: val_loss improved from 0.53655 to 0.52818, saving model to model.100epochs.hdf5
# Epoch 75/125
#  - 22s - loss: 0.5501 - accuracy: 0.8185 - val_loss: 0.5251 - val_accuracy: 0.8376
#
# Epoch 00075: val_loss improved from 0.52818 to 0.52511, saving model to model.100epochs.hdf5
# Epoch 76/125
#  - 22s - loss: 0.5433 - accuracy: 0.8229 - val_loss: 0.5291 - val_accuracy: 0.8328
#
# Epoch 00076: val_loss did not improve from 0.52511
# Epoch 77/125
#  - 22s - loss: 0.5372 - accuracy: 0.8246 - val_loss: 0.5309 - val_accuracy: 0.8306
#
# Epoch 00077: val_loss did not improve from 0.52511
# Epoch 78/125
#  - 22s - loss: 0.5356 - accuracy: 0.8242 - val_loss: 0.5018 - val_accuracy: 0.8374
#
# Epoch 00078: val_loss improved from 0.52511 to 0.50180, saving model to model.100epochs.hdf5
# Epoch 79/125
#  - 22s - loss: 0.5390 - accuracy: 0.8236 - val_loss: 0.5427 - val_accuracy: 0.8268
#
# Epoch 00079: val_loss did not improve from 0.50180
# Epoch 80/125
#  - 22s - loss: 0.5358 - accuracy: 0.8248 - val_loss: 0.5138 - val_accuracy: 0.8410
#
# Epoch 00080: val_loss did not improve from 0.50180
# Epoch 81/125
#  - 22s - loss: 0.5279 - accuracy: 0.8314 - val_loss: 0.5477 - val_accuracy: 0.8318
#
# Epoch 00081: val_loss did not improve from 0.50180
# Epoch 82/125
#  - 22s - loss: 0.5310 - accuracy: 0.8263 - val_loss: 0.5326 - val_accuracy: 0.8324
#
# Epoch 00082: val_loss did not improve from 0.50180
# Epoch 83/125
#  - 22s - loss: 0.5255 - accuracy: 0.8294 - val_loss: 0.5119 - val_accuracy: 0.8436
#
# Epoch 00083: val_loss did not improve from 0.50180
# Epoch 84/125
#  - 22s - loss: 0.5208 - accuracy: 0.8317 - val_loss: 0.5231 - val_accuracy: 0.8378
#
# Epoch 00084: val_loss did not improve from 0.50180
# Epoch 85/125
#  - 22s - loss: 0.5256 - accuracy: 0.8295 - val_loss: 0.5138 - val_accuracy: 0.8432
#
# Epoch 00085: val_loss did not improve from 0.50180
# Epoch 86/125
#  - 22s - loss: 0.5078 - accuracy: 0.8364 - val_loss: 0.5272 - val_accuracy: 0.8350
#
# Epoch 00086: val_loss did not improve from 0.50180
# Epoch 87/125
#  - 22s - loss: 0.5175 - accuracy: 0.8314 - val_loss: 0.5023 - val_accuracy: 0.8436
#
# Epoch 00087: val_loss did not improve from 0.50180
# Epoch 88/125
#  - 22s - loss: 0.5116 - accuracy: 0.8309 - val_loss: 0.5263 - val_accuracy: 0.8356
#
# Epoch 00088: val_loss did not improve from 0.50180
# Epoch 89/125
#  - 22s - loss: 0.5071 - accuracy: 0.8355 - val_loss: 0.5219 - val_accuracy: 0.8362
#
# Epoch 00089: val_loss did not improve from 0.50180
# Epoch 90/125
#  - 22s - loss: 0.5094 - accuracy: 0.8341 - val_loss: 0.4836 - val_accuracy: 0.8470
#
# Epoch 00090: val_loss improved from 0.50180 to 0.48357, saving model to model.100epochs.hdf5
# Epoch 91/125
#  - 22s - loss: 0.5063 - accuracy: 0.8352 - val_loss: 0.4822 - val_accuracy: 0.8536
#
# Epoch 00091: val_loss improved from 0.48357 to 0.48225, saving model to model.100epochs.hdf5
# Epoch 92/125
#  - 22s - loss: 0.5009 - accuracy: 0.8360 - val_loss: 0.4728 - val_accuracy: 0.8564
#
# Epoch 00092: val_loss improved from 0.48225 to 0.47284, saving model to model.100epochs.hdf5
# Epoch 93/125
#  - 22s - loss: 0.5070 - accuracy: 0.8345 - val_loss: 0.5004 - val_accuracy: 0.8494
#
# Epoch 00093: val_loss did not improve from 0.47284
# Epoch 94/125
#  - 22s - loss: 0.4937 - accuracy: 0.8384 - val_loss: 0.5275 - val_accuracy: 0.8396
#
# Epoch 00094: val_loss did not improve from 0.47284
# Epoch 95/125
#  - 22s - loss: 0.4998 - accuracy: 0.8389 - val_loss: 0.5157 - val_accuracy: 0.8404
#
# Epoch 00095: val_loss did not improve from 0.47284
# Epoch 96/125
#  - 22s - loss: 0.4959 - accuracy: 0.8410 - val_loss: 0.4863 - val_accuracy: 0.8504
#
# Epoch 00096: val_loss did not improve from 0.47284
# Epoch 97/125
#  - 22s - loss: 0.4965 - accuracy: 0.8393 - val_loss: 0.4900 - val_accuracy: 0.8484
#
# Epoch 00097: val_loss did not improve from 0.47284
# Epoch 98/125
#  - 22s - loss: 0.4935 - accuracy: 0.8390 - val_loss: 0.4856 - val_accuracy: 0.8460
#
# Epoch 00098: val_loss did not improve from 0.47284
# Epoch 99/125
#  - 22s - loss: 0.4834 - accuracy: 0.8432 - val_loss: 0.4839 - val_accuracy: 0.8522
#
# Epoch 00099: val_loss did not improve from 0.47284
# Epoch 100/125
#  - 22s - loss: 0.4862 - accuracy: 0.8406 - val_loss: 0.4917 - val_accuracy: 0.8510
#
# Epoch 00100: val_loss did not improve from 0.47284
# Epoch 101/125
#  - 22s - loss: 0.4783 - accuracy: 0.8444 - val_loss: 0.4684 - val_accuracy: 0.8588
#
# Epoch 00101: val_loss improved from 0.47284 to 0.46842, saving model to model.100epochs.hdf5
# Epoch 102/125
#  - 22s - loss: 0.4780 - accuracy: 0.8430 - val_loss: 0.4696 - val_accuracy: 0.8538
#
# Epoch 00102: val_loss did not improve from 0.46842
# Epoch 103/125
#  - 22s - loss: 0.4817 - accuracy: 0.8446 - val_loss: 0.4904 - val_accuracy: 0.8490
#
# Epoch 00103: val_loss did not improve from 0.46842
# Epoch 104/125
#  - 22s - loss: 0.4753 - accuracy: 0.8454 - val_loss: 0.4496 - val_accuracy: 0.8636
#
# Epoch 00104: val_loss improved from 0.46842 to 0.44963, saving model to model.100epochs.hdf5
# Epoch 105/125
#  - 22s - loss: 0.4682 - accuracy: 0.8478 - val_loss: 0.4758 - val_accuracy: 0.8520
#
# Epoch 00105: val_loss did not improve from 0.44963
# Epoch 106/125
#  - 22s - loss: 0.4703 - accuracy: 0.8466 - val_loss: 0.4739 - val_accuracy: 0.8558
#
# Epoch 00106: val_loss did not improve from 0.44963
# Epoch 107/125
#  - 22s - loss: 0.4717 - accuracy: 0.8481 - val_loss: 0.4905 - val_accuracy: 0.8426
#
# Epoch 00107: val_loss did not improve from 0.44963
# Epoch 108/125
#  - 22s - loss: 0.4696 - accuracy: 0.8484 - val_loss: 0.4868 - val_accuracy: 0.8532
#
# Epoch 00108: val_loss did not improve from 0.44963
# Epoch 109/125
#  - 22s - loss: 0.4693 - accuracy: 0.8464 - val_loss: 0.4828 - val_accuracy: 0.8488
#
# Epoch 00109: val_loss did not improve from 0.44963
# Epoch 110/125
#  - 22s - loss: 0.4622 - accuracy: 0.8509 - val_loss: 0.4668 - val_accuracy: 0.8556
#
# Epoch 00110: val_loss did not improve from 0.44963
# Epoch 111/125
#  - 22s - loss: 0.4669 - accuracy: 0.8491 - val_loss: 0.4668 - val_accuracy: 0.8516
#
# Epoch 00111: val_loss did not improve from 0.44963
# Epoch 112/125
#  - 22s - loss: 0.4613 - accuracy: 0.8506 - val_loss: 0.4746 - val_accuracy: 0.8560
#
# Epoch 00112: val_loss did not improve from 0.44963
# Epoch 113/125
#  - 22s - loss: 0.4639 - accuracy: 0.8510 - val_loss: 0.4634 - val_accuracy: 0.8574
#
# Epoch 00113: val_loss did not improve from 0.44963
# Epoch 114/125
#  - 22s - loss: 0.4627 - accuracy: 0.8496 - val_loss: 0.4427 - val_accuracy: 0.8670
#
# Epoch 00114: val_loss improved from 0.44963 to 0.44267, saving model to model.100epochs.hdf5
# Epoch 115/125
#  - 22s - loss: 0.4585 - accuracy: 0.8524 - val_loss: 0.4388 - val_accuracy: 0.8666
#
# Epoch 00115: val_loss improved from 0.44267 to 0.43883, saving model to model.100epochs.hdf5
# Epoch 116/125
#  - 22s - loss: 0.4470 - accuracy: 0.8560 - val_loss: 0.4616 - val_accuracy: 0.8542
#
# Epoch 00116: val_loss did not improve from 0.43883
# Epoch 117/125
#  - 22s - loss: 0.4520 - accuracy: 0.8540 - val_loss: 0.4779 - val_accuracy: 0.8532
#
# Epoch 00117: val_loss did not improve from 0.43883
# Epoch 118/125
#  - 22s - loss: 0.4533 - accuracy: 0.8537 - val_loss: 0.4635 - val_accuracy: 0.8568
#
# Epoch 00118: val_loss did not improve from 0.43883
# Epoch 119/125
#  - 22s - loss: 0.4442 - accuracy: 0.8588 - val_loss: 0.4793 - val_accuracy: 0.8538
#
# Epoch 00119: val_loss did not improve from 0.43883
# Epoch 120/125
#  - 22s - loss: 0.4494 - accuracy: 0.8540 - val_loss: 0.4520 - val_accuracy: 0.8574
#
# Epoch 00120: val_loss did not improve from 0.43883
# Epoch 121/125
#  - 22s - loss: 0.4515 - accuracy: 0.8562 - val_loss: 0.4459 - val_accuracy: 0.8646
#
# Epoch 00121: val_loss did not improve from 0.43883
# Epoch 122/125
#  - 22s - loss: 0.4443 - accuracy: 0.8553 - val_loss: 0.4432 - val_accuracy: 0.8622
#
# Epoch 00122: val_loss did not improve from 0.43883
# Epoch 123/125
#  - 22s - loss: 0.4467 - accuracy: 0.8562 - val_loss: 0.4416 - val_accuracy: 0.8648
#
# Epoch 00123: val_loss did not improve from 0.43883
# Epoch 124/125
#  - 22s - loss: 0.4511 - accuracy: 0.8549 - val_loss: 0.4608 - val_accuracy: 0.8588
#
# Epoch 00124: val_loss did not improve from 0.43883
# Epoch 125/125
#  - 22s - loss: 0.4349 - accuracy: 0.8602 - val_loss: 0.4579 - val_accuracy: 0.8608
#
# Epoch 00125: val_loss did not improve from 0.43883

# %%
plt.plot(history.history['accuracy'],label='train')
plt.plot(history.history['val_accuracy'],label='Validation')
plt.legend()
plt.show()
